# %% [markdown]
# En este notebook se incluye:
#
# 1. Tratamiento de valores faltantes
#
# 2. Identificación y gestión de duplicados
#
# 3. Detección y manejo de outliers
#
# 4. Eliminación de columnas innecesarias
#
# 5. Conversión de tipos de datos
#
# 6. Estandarización o normalización (si aplica)
