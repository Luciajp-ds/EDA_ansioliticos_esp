# %% [markdown]
# # Preprocesado de datos
# En este notebook se incluye:
#
# 1. Unir los datos en un único dataset (en nuestro caso no procede)
#
# 2. convertir a formato estructurado (en nuestro caso no procede)
#
# 3. Documentar el origen de cada fuente de datos
